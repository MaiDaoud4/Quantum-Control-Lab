# %% [markdown]
# <a href="https://colab.research.google.com/github/MaiDaoud4/Quantum-Control-Lab/blob/main/First_Quantum_Circuit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install qiskit-aer
# !pip install qiskit[visualization]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136817 sha256=97605415d579bfb11fd43f5b51a385fe70011aba9a4bcf729c34260e02529439
#   Stored in directory: /root/.cache/pip/wheels/06/3e/78/fa1588c1ae991bbfd814af2bcac6cef7a178beee1939180d46
# Successfully built pylatexenc
# ...

# %%
from qiskit import QuantumCircuit
from qiskit.visualization import plot_bloch_multivector
import matplotlib.pyplot as plt

# %%
qc=QuantumCircuit(1)
qc.h(0)

# %%
print("Bloch")
qc.draw('text')
# Out:
# Bloch
#    ┌───┐
# q: ┤ H ├
#    └───┘

# %%
qc_v2=QuantumCircuit(1)
qc_v2.x(0)
qc_v2.h(0)
qc_v2.draw('mpl')
